# %% [markdown]
# # 华为云 CCE 部署 Nginx 实践
#
# 本案例参考华为云 CCE 常见上手流程，目标是让用户完成一个可访问的 Nginx 工作负载。

# %% [markdown]
# ## 学习目标
#
# - 理解集群、节点池、命名空间的基础关系
# - 使用 `kubectl` 创建 Deployment 与 Service
# - 验证工作负载状态并查看日志

# %% [markdown]
# ## 参考资料
#
# - 华为云 CCE 容器工作负载流程说明
# - 华为云社区：CCE 部署 Nginx 实战文章
# - Kubernetes 官方文档：Deployment / Service
