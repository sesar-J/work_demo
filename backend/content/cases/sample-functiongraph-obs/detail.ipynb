# %% [markdown]
# # 华为云 FunctionGraph + OBS 图片处理实践
#
# 本案例采用华为云常见的事件驱动架构：当图片上传到 OBS 时，自动触发函数处理并输出到目标桶。

# %% [markdown]
# ## 学习目标
#
# - 理解 OBS 事件与 FunctionGraph 触发机制
# - 配置函数运行时、超时、内存等关键参数
# - 通过上传文件验证触发链路是否成功

# %% [markdown]
# ## 适用场景
#
# - 图片压缩与格式转换
# - 文件病毒扫描/内容审核前处理
# - 对象上传后自动生成缩略图
