# %% [markdown]
# # 操作步骤（FunctionGraph + OBS）
#
# 本页用于指导你在右侧环境完成触发器实践。

# %% [markdown]
# ## Step 1: 创建 OBS 桶
#
# - `fg-input-bucket`：输入图片
# - `fg-output-bucket`：输出处理后图片

# %% [markdown]
# ## Step 2: 创建并发布函数
#
# 建议语言选择 Python，先使用最小逻辑（读取事件并打印对象名），再增加图片处理逻辑。

# %%
# 示例：函数核心伪代码
def handler(event, context):
    print('event:', event)
    # 1. 从输入桶读取对象
    # 2. 执行处理逻辑（压缩/转码）
    # 3. 上传到输出桶
    return {'statusCode': 200}

# %% [markdown]
# ## Step 3: 绑定 OBS 触发器并验证
#
# 上传测试图片后，检查函数日志和输出桶文件，确认触发链路成功。
