# %% [markdown]
# # 操作页文档（左侧）
#
# 请在右侧 Notebook 中逐步执行命令，并根据注释创建对应文件。

# %% [markdown]
# ## version.tf
#
# 声明 Terraform 与 provider 版本。

# %% [markdown]
# ## variables.tf / main.tf / terraform.tfvars
#
# - `variables.tf` 定义输入变量
# - `main.tf` 定义核心资源（VPC/子网/安全组）
# - `terraform.tfvars` 填实际参数（AK/SK 在 notebook 环境输入）

# %%
terraform init
terraform plan
terraform apply -auto-approve
